# %% [markdown]
# # Pandas数据处理120题知识点总结
# ## 第二章 查看数据基本信息

# %% [markdown]
# ---
#
# 　ID：wlong
# 　数据分析爱好者、目前小白一枚
# 　邮箱：wlong826@163.com
# 　CSDN：**[【数分小白龙】](https://blog.csdn.net/qq_38230663)**
# 　和鲸社区：**[【wlong】](https://www.heywhale.com/home/user/profile/5f0a61d72be199002c073935)**
# 　如果有不完善的地方，欢迎小伙伴评论区留言！
# 　最近博客、和鲸每周都会有所更新，欢迎大家**关注点赞分享**哦！
#
# ---
#
# 　本文的CSDN链接：[【二、查看数据基本信息】](https://blog.csdn.net/qq_38230663/article/details/116396965?spm=1001.2014.3001.5501)
#
#  　如果有想学习爬虫的小伙伴，可以看这里：[【零基础入门Python爬虫--豆瓣、58同城、安居客等】](https://www.heywhale.com/mw/project/60be1fa8acdcb3001707b133)
#
#  　关于总结更详细的配套习题案例，看这👉：[【和鲸训练营第一期——Pandas基础】](https://www.heywhale.com/home/competition/60c086d8565cca001731537f)

# %%
import pandas as pd
import numpy as np

# %%
data = {"grammer":['Python', 'C', 'Java', 'GO', 'css', 'SQL', 'PHP', 'Python'],
       "score":[1.0, 2.0, 6.0, 4.0, 5.0, 6.0, 7.0, 10.0]}
df = pd.DataFrame(data)
df
# Out:
#   grammer  score
# 0  Python    1.0
# 1       C    2.0
# 2    Java    6.0
# 3      GO    4.0
# 4     css    5.0
# 5     SQL    6.0
# 6     PHP    7.0
# 7  Python   10.0

# %% [markdown]
# ## 1 查看前(后)5行数据

# %%
#前5行：
df.head() # 默认是5
# Out:
#   grammer  score
# 0  Python    1.0
# 1       C    2.0
# 2    Java    6.0
# 3      GO    4.0
# 4     css    5.0

# %%
#后5行：
# 方法一：
df.tail() # 默认是5
# 方法二：
df.iloc[-5:, :]
# Out:
#   grammer  score
# 3      GO    4.0
# 4     css    5.0
# 5     SQL    6.0
# 6     PHP    7.0
# 7  Python   10.0

# %% [markdown]
# ## 2. 查看所有列名

# %%
df.columns
# Out:
# Index(['grammer', 'score'], dtype='object')

# %% [markdown]
# ## 3. 查看数据行列数

# %%
df.shape
# Out:
# (8, 2)

# %% [markdown]
# ## 4. 查看行数

# %%
#方法一：
df.shape[0]
#方法二；
len(df)
# Out:
# 8

# %% [markdown]
# ## 5. 查看列数

# %%
#方法一：
len(df.columns)
#方法二：
df.shape[1]
# Out:
# 2

# %% [markdown]
# ## 6. 查看索引、数据类型和内存信息

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   grammer  8 non-null      object
#  1   score    8 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# ## 7. 查看索引

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %% [markdown]
# ## 8. 查看数值型列的汇总统计

# %%
df.describe()
# Out:
#            score
# count   8.000000
# mean    5.125000
# std     2.850439
# min     1.000000
# 25%     3.500000
# 50%     5.500000
# 75%     6.250000
# max    10.000000

# %% [markdown]
# ## 9. 查看每列的数据类型

# %%
df.dtypes
# Out:
# grammer     object
# score      float64
# dtype: object

# %% [markdown]
# ## 10. 查看某列共有几种元素

# %%
#方法一：
df['grammer'].nunique()
#方法二：
len(df['grammer'].unique())
#方法三：
len(df.groupby('grammer'))
#方法四：
len(df['grammer'].value_counts())
# Out:
# 7

# %% [markdown]
# ## 11. 查看pandas与numpy版本

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 1.2.4
# 1.20.3

# %% [markdown]
# ## 12. 查看某一列各元素出现的次数

# %%
df['grammer'].value_counts()
# Out:
# Python    2
# css       1
# SQL       1
# GO        1
# Java      1
# C         1
# PHP       1
# Name: grammer, dtype: int64

# %% [markdown]
# ## 13. 查看某列每个字符串的长度

# %%
# 方法一：
df['grammer'].map(lambda x: len(x))
# 方法二：
df['grammer'].str.len()
# Out:
# 0    6
# 1    1
# 2    4
# 3    2
# 4    3
# 5    3
# 6    3
# 7    6
# Name: grammer, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# # 最后附上思维导图：
#
# ![Image Name](https://cdn.kesci.com/upload/image/quhbch2sc9.png)
